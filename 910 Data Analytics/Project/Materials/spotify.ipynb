# %%
import pandas as pd
data = pd.read_csv('dataset.csv')
data.head()
# Out:
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       444171         0.446   0.651    5   -13.349     1       0.3120
# 1       186513         0.584   0.570    1    -7.478     1       0.0289
# 2       196466         0.489   0.349    2   -14.295     0       0.0323
# 3       257828         0.246   0.630    0    -5.551     1       0.0336
# 4       198762         0.486   0.892    7    -3.529     1       0.0606
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0       0.64200          0.000421    0.8820    0.597  123.092               4
# 1       0.47900          0.000000    0.1000    0.331   94.993               1
# 2       0.67600          0.078900    0.0866    0.622  124.348               4
# 3       0.00084          0.008800    0.2920    0.211  126.457               4
# 4       0.07740          0.000000    0.0532    0.361   72.984               4
#
#   track_genre
# 0       blues
# 1       blues
# 2       blues
# 3       blues
# 4       blues

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key",
    "liveness", "loudness", "mode", "speechiness", "tempo", "time_signature", "valence"]

normalized = data.copy()
for feature in features:
    normalized[feature] = (data[feature] - data[feature].min()) / (data[feature].max() - data[feature].min())

# %%
normalized.describe()
# Out:
#        duration_ms  danceability      energy         key    loudness  \
# count   900.000000    900.000000  900.000000  900.000000  900.000000
# mean      0.073748      0.591758    0.593269    0.470808    0.769333
# std       0.053310      0.173706    0.265005    0.321822    0.153523
# min       0.000000      0.000000    0.000000    0.000000    0.000000
# 25%       0.053503      0.466391    0.407343    0.181818    0.727681
# 50%       0.066399      0.596691    0.636759    0.454545    0.817153
# 75%       0.083174      0.724922    0.806808    0.727273    0.867783
# max       1.000000      1.000000    1.000000    1.000000    1.000000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  900.000000   900.000000    900.000000        900.000000  900.000000
# mean     0.642222     0.127822      0.351342          0.120368    0.184632
# std      0.479613     0.129985      0.353664          0.290506    0.160066
# min      0.000000     0.000000      0.000000          0.000000    0.000000
# 25%      0.000000     0.058803      0.033765          0.000000    0.082197
# 50%      1.000000     0.077436      0.211555          0.000017    0.116519
# 75%      1.000000     0.126667      0.643466          0.004854    0.252317
# max      1.000000     1.000000      1.000000          1.000000    1.000000
#
#           valence       tempo  time_signature
# count  900.000000  900.000000      900.000000
# mean     0.521791    0.586758        0.778222
# std      0.250011    0.148793        0.085768
# min      0.000000    0.000000        0.000000
# 25%      0.327041    0.467355        0.800000
# 50%      0.520408    0.584532        0.800000
# 75%      0.721939    0.685241        0.800000
# max      1.000000    1.000000        1.000000

# %%
normalized.to_csv('normalized.csv')
